# %%
import argparse
from random import randint, choice
import pandas as pd
import numpy as np
import re
import networkx as nx
import os 

import sys


from VMs import VM, Flavor_VM
from LOG_MSG import Log_msg
from SERVERS import Server, Type_Server
from SCHEDULERS import Scheduler


from collections import defaultdict
import json

# %%
class G_Tasks(nx.DiGraph):
    
    def __init__(self, name, tasks_list, servers_tasks:pd.DataFrame, vms_tasks:pd.DataFrame, default_server:Server):
        super().__init__()
        self.logger = Log_msg(name,"TASK")
        self.default_server = default_server
        
        for _t in tasks_list:
            self.add_edge(_t[0] if pd.notnull(_t[0]) else 'ROOT',_t[1], label=_t[2])
            
        for _n in self.nodes():
            nx.set_node_attributes(self,{_n: { "scheduler": Scheduler(_n, self.default_server)}})
            
        self.servers_tasks = servers_tasks
        self.vms_tasks = vms_tasks
    
    
    def get_predecessor(self, node):
        _predecessor = list(self.predecessors(node))
        
        if len(_predecessor) > 0:
            return _predecessor[0]
        
        return None

    
    def get_tasks(self, task_id=None):
        _ret = nx.to_pandas_edgelist(self)
        
        if task_id != None:
            _ret = _ret[_ret['task_id'] == task_id]
            
        return _ret
    
    def get_scheduler(self, task_name):
        
        for _n in self.nodes(data=True):
            if _n[0] == task_name:
                return _n[1]['scheduler']
            
        return None
          

    def execute_servers_task(self, task_name):      
        _predecessor = self.get_predecessor(task_name)
        _sch = self.nodes[_predecessor]['scheduler'].get_copy(task_name) if _predecessor else Scheduler(task_name, DEFAULT_SERVER)

        nx.set_node_attributes(self,{task_name: { "scheduler": _sch}})
        
        _tasks_servers = self.servers_tasks[self.servers_tasks['Task_Name'] == task_name]

        num_servers = len(_tasks_servers)
        for i,(k,cmd_v) in enumerate(_tasks_servers.iterrows()):
            #clear_output(wait=True)
            print("SCHEDULER SERVER: %s SERVER: %s EXC: %s AVZ: %s ..........%d of %d"%(_sch.name, cmd_v.Hostname, cmd_v.Task_Action, cmd_v.Avz, i+1,num_servers))
            
            if cmd_v.Task_Action == 'DELETE_ALL':
           
                for k,v in _sch.get_servers_status().groupby('server').max().iterrows():

                    if _sch.remove_server(k):
                        print("Deleted ALL Servers: %s"%k)
                        self.logger.log_msg('EXEC_SERVER_DELETE_ALL','OK',"Server deleted: %s"%k)
                    else:
                        print("ERROR: Deleted ALL Servers: %s"%k)
                        self.logger.log_msg('EXEC_SERVER_DELETE_ALL','NOK',"Server NOT deleted: %s"%k)
            
            
            if cmd_v.Task_Action == 'SET_DEFAULT_SERVER':
                _server = Server(cmd_v.Hostname, SERVER_TYPES[cmd_v.Server_Type], avz=cmd_v['Avz'], datacenter=cmd_v['Datacenter'])
                _sch.set_default_server(_server)
                self.logger.log_msg('EXEC_SERVER_DEFAULT_SERVER','OK',"Set new Default Server: %s"%cmd_v.Hostname)
            
            
            if cmd_v.Task_Action == 'CREATE':
                _server = Server(cmd_v.Hostname, SERVER_TYPES[cmd_v.Server_Type], avz=cmd_v['Avz'], datacenter=cmd_v['Datacenter'])
                
                if _sch.deploy_server(_server):
                    self.logger.log_msg('EXEC_SERVER_CREATE','OK',"Server  created: %s"%cmd_v.Hostname)
                else:
                    self.logger.log_msg('EXEC_SERVER_CREATE','NOK',"Server not created: %s"%cmd_v.Hostname)
            
            
            if cmd_v.Task_Action == 'DELETE':
                if _sch.remove_server(cmd_v.Hostname):
                    self.logger.log_msg('EXEC_SERVER_DELETE','OK',"Server deleted: %s"%cmd_v.Hostname)
                else:
                    self.logger.log_msg('EXEC_SERVER_DELETE','NOK',"Server NOT deleted: %s"%cmd_v.Hostname)


    def execute_vms_task(self, task_name, tries=2):

        def deploy_vm_try(_scheduler, cmd_v):
            
            _vm = VM(
                cmd_v.Vm_Name,
                cmd_v.Component,
                cmd_v.VNF,
                FLAVORS_VM[cmd_v.Flavor],
                avz=cmd_v.Avz,
                datacenter=cmd_v.Datacenter,
                node_select=cmd_v.Hostname,
                affinity=cmd_v.Affinity, 
                antiaffinity=cmd_v.AntiAffinity
                )
            
            _cluster_id, _status = _scheduler.rank_server_for_vm(_vm)
            
            return _cluster_id, _status ,_vm

        _sch = self.get_scheduler(task_name)
        _tasks_vms = self.vms_tasks[self.vms_tasks['Task_Name'] == task_name]
        
        num_vms = len(_tasks_vms)
        for i,(k,cmd_v) in enumerate(_tasks_vms.iterrows()):
            #clear_output(wait=True)
            print("SCHEDULER VM: %s VM: %s EXC: %s AVZ: %s  NODE_SELECT: %s ..........%d of %d"%(_sch.name, cmd_v.Vm_Name, cmd_v.Task_Action, cmd_v.Avz,cmd_v.Hostname, i+1,num_vms))
            
            if cmd_v.Task_Action == 'DELETE_ALL':
                print("Deleting all VMS....")
                self.logger.log_msg('EXEC_VMS_TASKS_DELETE_ALL','OK',"VM deleted all")
                for k,v in _sch.get_vms_status().iterrows():
                    
                    if _sch.remove_vm(v.vm):
                        print("VM deleted: %s"%(v.vm))
                        self.logger.log_msg('EXEC_VMS_TASKS_DELETE_ALL','OK',"VM deleted %s"%(v.vm))
                    else:
                        print("VM NOT deleted: %s"%(v.vm))
                        self.logger.log_msg('EXEC_VMS_TASKS_DELETE_ALL','NOK',"VM NOT deleted %s"%(v.vm))
                        
              
            if cmd_v.Task_Action == 'C1REATE':
                if _sch.get_vm_by_name(cmd_v.Vm_Name) != None:
                    print("This VM Already exist: %s"%cmd_v.Vm_Name)
                    self.logger.log_msg('EXEC_VMS_CREATE','NOK',"This VM Already exist: %s"%cmd_v.Vm_Name)
                    continue
                    
                _cluster_id, _status, _vm = deploy_vm_try(_sch, cmd_v)
                
                try_deploy = 0
                while (_cluster_id < 0) & (try_deploy < tries):
                    df_server = _sch.create_default_server(avz=cmd_v.Avz, datacenter=cmd_v.Datacenter)
                    print("No enough resources, needed %d, creating Default Server: %s"%(_vm.flavor.vcpus,df_server.name))
                    print("Try %d"%try_deploy)
                    self.logger.log_msg('EXEC_VMS_CREATE','NOK',"No enough resources, needed %d, creating Default Server: %s"%(_vm.flavor.vcpus,df_server.name))
                    
                    _cluster_id, _status, _vm = deploy_vm_try(_sch, cmd_v)

                    try_deploy += 1

                if _cluster_id >= 0:
                    print("Deployed VM: %s in Server: %s \r"%(_vm.name, _sch.servers[_cluster_id].name), end='')
                    self.logger.log_msg('EXEC_VMS_CREATE','OK',"Resources  %d found, in server id: %s"%(_vm.flavor.vcpus,_cluster_id))
                    if not _sch.deploy_vm(_sch.servers[_cluster_id].name,_vm):
                        print("ERROR:   en %s"%_sch.servers[_cluster_id].name)
                else:
                    print("Could not Deployed VM: %s"%_vm.name)
                    self.logger.log_msg('EXEC_VMS_CREATE','OK',"Resources  %d vcpus not found"%(_vm.flavor.vcpus))
                    
            #### DEV100   
            if cmd_v.Task_Action == 'CREATE':
                try_deploy = 0
                _vm = VM(
                    cmd_v.Vm_Name,
                    cmd_v.Component,
                    cmd_v.VNF,
                    FLAVORS_VM[cmd_v.Flavor],
                    avz=cmd_v.Avz,
                    datacenter=cmd_v.Datacenter,
                    node_select=cmd_v.Hostname,
                    affinity=cmd_v.Affinity, 
                    antiaffinity=cmd_v.AntiAffinity)
                
                
                _id, _status = _sch.rank_server_for_vm(_vm)
                
                while (_id < 0) & (try_deploy < tries):
                    df_server = _sch.create_default_server(avz=cmd_v.Avz, datacenter=cmd_v.Datacenter)
                    print("No enough resources, needed %d, creating Default Server: %s"%(_vm.flavor.vcpus,df_server.name))
                    print("Try %d"%try_deploy)
                    self.logger.log_msg('EXEC_VMS_CREATE','NOK',"No enough resources, needed %d, creating Default Server: %s"%(_vm.flavor.vcpus,df_server.name))
                    
                    _id, _status = _sch.rank_server_for_vm(_vm)
                    try_deploy += 1
                
                if _id >= 0:
                    print("Deployed VM: %s in Server: %s \r"%(_vm.name, _sch.servers[_id].name), end='')
                    self.logger.log_msg('EXEC_VMS_CREATE','OK',"Resources  %d found, in server id: %s"%(_vm.flavor.vcpus,_id))
                    
                    if not _sch.deploy_vm(_sch.servers[_id],_vm):
                        print("ERROR: Incongruencia con server  %s y VM %s"%(_sch.servers[_id].name,_vm.name))
                        print(_status)
                else:
                    print("Could not Deployed VM: %s"%_vm.name)
                    self.logger.log_msg('EXEC_VMS_CREATE','OK',"Resources  %d vcpus not found"%(_vm.flavor.vcpus))
                    
            
            
            if cmd_v.Task_Action == 'DELETE':   
                if _sch.remove_vm(cmd_v.Vm_Name):
                    print("VM deleted: %s"%(cmd_v.Vm_Name))
                    self.logger.log_msg('EXEC_VMS_DELETE','OK',"VM deleted %s"%(cmd_v.Vm_Name))
                else:
                    print("VM NOT deleted: %s"%(cmd_v.Vm_Name))
                    self.logger.log_msg('EXEC_VMS_DELETE','NOK',"VM NOT deleted %s"%(cmd_v.Vm_Name))

# %%
def format_server_df(file):
    _sheet_name = 'Servers'
    _columns_strip = ['Task_Name','Task_Action','Hostname','Avz','Datacenter']
    _columns_int = ['Server_Type']
    
    _servers_df = pd.read_excel(file, sheet_name=_sheet_name)
    _servers_df.loc[:,['Avz','Datacenter']] = _servers_df.loc[:,['Avz','Datacenter']].fillna('default')
    _servers_df[_columns_strip] = _servers_df[_columns_strip].fillna('').applymap(lambda x: x.strip())
    _servers_df[_columns_int] = _servers_df[_columns_int].fillna(-1).astype(int)
    
    return _servers_df
  
    
def format_vms_df(file):
    _sheet_name = 'VMs'
    _columns_strip = ['Task_Name','Task_Action','Vm_Name','Hostname','Avz','Component','VNF', 'Datacenter']
    _columns_int = ['Flavor']
    
    _vms_df = pd.read_excel(file, sheet_name='VMs')
    _vms_df.loc[:,['Avz','Datacenter']] = _vms_df.loc[:,['Avz','Datacenter']].fillna('default')
    _vms_df.loc[:,['Vm_Name','Hostname']] = _vms_df.loc[:,['Vm_Name','Hostname']].fillna('')
    _vms_df[_columns_strip] = _vms_df[_columns_strip].fillna('').applymap(lambda x: x.strip())
    _vms_df['Affinity'] = _vms_df['Affinity'].fillna('').apply(lambda x: [y for y in x.split(',') if y != ''] if re.match(r'([a-zA-Z0-9_-]+,)+',x) else [])
    _vms_df['AntiAffinity'] = _vms_df['AntiAffinity'].fillna('').apply(lambda x: [y for y in x.split(',') if y != ''] if re.match(r'([a-zA-Z0-9_-]+,)+',x) else [])
    _vms_df[_columns_int] = _vms_df[_columns_int].fillna(-1).astype(int)
    
    return _vms_df[_columns_strip + _columns_int +['Affinity','AntiAffinity']]
    

def format_flavors_df(file):
    _columns_strip = ['Compute_Type']
    _columns_int = ['Id','Vcpus','RAM']
    
    _flavors_df = pd.read_excel(file, sheet_name='Flavor_Types')
    _flavors_df[_columns_strip] = _flavors_df[_columns_strip].applymap(lambda x: x.strip())
    _flavors_df[_columns_int] = _flavors_df[_columns_int].astype(int)
    _flavors_df = _flavors_df.set_index('Id')
    
    return [Flavor_VM(k, v.Vcpus, v.RAM) for k,v in _flavors_df.iterrows()]


def format_server_types(file):
    _columns_strip = ['Processor_Model','HyperThreading']
    _columns_int = ['Id','Num_Cores','Vcpus_for_System','Ram_memory_GB']
    _server_type_df = pd.read_excel(file, sheet_name='Server_Types')
    _server_type_df[_columns_strip] = _server_type_df[_columns_strip].applymap(lambda x: x.strip())
    _server_type_df[_columns_int] = _server_type_df[_columns_int].astype(int)
    _server_type_df['HyperThreading'] = _server_type_df['HyperThreading'].apply(lambda x: True if x == 'yes' else False)
    _server_type_df = _server_type_df.set_index('Id')
        
    return  [Type_Server(k, 
                         v.Num_Cores, 
                         v.Vcpus_per_Core, 
                         v.Vcpus_for_System, 
                         v.HyperThreading, 
                         v.Ram_memory_GB, 
                         v.Processor_Model) for k,v in _server_type_df.iterrows()]


def format_task_df(file):
    _task_df = pd.read_excel(file, sheet_name='Tasks')
    _task_df[['Previous_Task','Fordward_Task']] = _task_df[['Previous_Task','Fordward_Task']].applymap(lambda x: x.strip() if type(x) == str else x)
    
    return _task_df


def exec_tasks(tasks, task_name):
    print("\n\n############################################################################")
    print("Exceuting TASK:          %s"%task_name)
    tasks.execute_servers_task(task_name)
    tasks.execute_vms_task(task_name)

    for _sucessor in tasks.successors(task_name):
        exec_tasks(tasks, _sucessor) 

if True:
    file_path = "../template_nfvi_report_20220503_v3.7.xlsx"
    
    print("reading FILE: Servers Types")
    SERVER_TYPES = format_server_types(file_path)

    print("reading FILE: Flavors VMs")
    FLAVORS_VM = format_flavors_df(file_path)

    print("reading FILE: Servers")
    SERVERS_DF = format_server_df(file_path)

    print("reading FILE: VMs")
    VMS_DF = format_vms_df(file_path)


    print("reading FILE: Tasks")
    TASKS_DF = format_task_df(file_path)

    DEFAULT_SERVER = Server('default_server',SERVER_TYPES[0],'default', 'default', virtual=True)
    
    TASKS  = G_Tasks('PRI_TASK',TASKS_DF.values, SERVERS_DF, VMS_DF, DEFAULT_SERVER)
    exec_tasks(TASKS, 'INITIALIZATION')
    
    print("AVZ tables...")
    AVZ_TABLES = {_node:TASKS.get_scheduler(_node).get_status_by_avz()  for _node in TASKS.nodes() if _node != 'ROOT'}
    for k,v in AVZ_TABLES.items():
        v['utilization'] = v['utilization'].apply(lambda x: "%0.0f%%"%(100*x)) 
            
    print("Creating Server tables...")
    SERVERS_TABLES = {_node:TASKS.get_scheduler(_node).get_servers_status()  for _node in TASKS.nodes() if _node != 'ROOT'}
    for k,v in SERVERS_TABLES.items():
        v.loc[:,['id','memory','server_type','vcpus','vcpus_free','vcpus_reserved','vcpus_system','vms']] = v.loc[:,['id','memory','server_type','vcpus','vcpus_free','vcpus_reserved','vcpus_system','vms']].astype(int)

    print("Creating VMs tables...")
    VMS_TABLES = {_node:TASKS.get_scheduler(_node).get_vms_status()  for _node in TASKS.nodes() if _node != 'ROOT'}
    for k,v in VMS_TABLES.items():
        v.loc[:,['vcpus','memory']] = v.loc[:,['vcpus','memory']].astype(int)
# Out:
# reading FILE: Servers Types
# reading FILE: Flavors VMs
# reading FILE: Servers
# reading FILE: VMs
# reading FILE: Tasks
#
#
# ############################################################################
# Exceuting TASK:          INITIALIZATION
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2164 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........1 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2010 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00 ..........2 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2013 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00 ..........3 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2017 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........4 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2007 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00 ..........5 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2168 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........6 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2012 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00 ..........7 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2002 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00 ..........8 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2160 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........9 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2009 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00 ..........10 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2001 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00 ..........11 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2161 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........12 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2162 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........13 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2008 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00 ..........14 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2165 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........15 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2014 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........16 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2015 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........17 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2158 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........18 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2901 EXC: CREATE AVZ: default_lry ..........19 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2011 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00 ..........20 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2019 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........21 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2020 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........22 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2004 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00 ..........23 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2163 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........24 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2170 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........25 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2903 EXC: CREATE AVZ: default_lry ..........26 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2043 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02 ..........27 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2026 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........28 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2153 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........29 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2045 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02 ..........30 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2042 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02 ..........31 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2032 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........32 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2040 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........33 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2039 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........34 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2028 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........35 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2031 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........36 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2027 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........37 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2054 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03 ..........38 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2038 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........39 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2050 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03 ..........40 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2053 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03 ..........41 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2051 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03 ..........42 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2157 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........43 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2037 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........44 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2156 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........45 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2152 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........46 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2155 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........47 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2049 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03 ..........48 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2151 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........49 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2033 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........50 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2035 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03 ..........51 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2024 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........52 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2034 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02 ..........53 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2047 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02 ..........54 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2046 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02 ..........55 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2052 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03 ..........56 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2048 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03 ..........57 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2044 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02 ..........58 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2055 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03 ..........59 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2036 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........60 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2159 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........61 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2167 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........62 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2006 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00 ..........63 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2166 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........64 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2030 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........65 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2056 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03 ..........66 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2022 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........67 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2005 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00 ..........68 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2003 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00 ..........69 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2016 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........70 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2041 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........71 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2902 EXC: CREATE AVZ: default_lry ..........72 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2069 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........73 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2065 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........74 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2057 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........75 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2062 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........76 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2060 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........77 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2061 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........78 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2066 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........79 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2058 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........80 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2070 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........81 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2075 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........82 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2071 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........83 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2063 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........84 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2073 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........85 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2067 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........86 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2072 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........87 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2064 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........88 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2068 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........89 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2059 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........90 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2154 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04 ..........91 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2029 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........92 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2021 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........93 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2169 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........94 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-cllry01-csu-2025 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01 ..........95 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2023 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........96 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2026 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........97 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2152 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........98 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2045 EXC: CREATE AVZ: clesb01-vapp1-ceeaz02 ..........99 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2151 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........100 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2002 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00 ..........101 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2901 EXC: CREATE AVZ: default_esb ..........102 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2024 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........103 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2044 EXC: CREATE AVZ: clesb01-vapp1-ceeaz02 ..........104 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2047 EXC: CREATE AVZ: clesb01-vapp1-ceeaz02 ..........105 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2157 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........106 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2019 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........107 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2021 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........108 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2025 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........109 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2022 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........110 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2017 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........111 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2043 EXC: CREATE AVZ: clesb01-vapp1-ceeaz02 ..........112 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2032 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........113 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2055 EXC: CREATE AVZ: clesb01-vapp1-ceeaz03 ..........114 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2016 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........115 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2902 EXC: CREATE AVZ: default_esb ..........116 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2158 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........117 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2036 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........118 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2027 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........119 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2003 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00 ..........120 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2029 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........121 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2903 EXC: CREATE AVZ: default_esb ..........122 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2030 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........123 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2040 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........124 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2033 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........125 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2042 EXC: CREATE AVZ: clesb01-vapp1-ceeaz02 ..........126 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2039 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........127 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2007 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00 ..........128 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2014 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........129 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2008 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00 ..........130 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2005 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00 ..........131 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2009 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00 ..........132 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2015 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........133 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2004 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00 ..........134 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2011 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00 ..........135 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2010 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00 ..........136 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2013 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00 ..........137 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2049 EXC: CREATE AVZ: clesb01-vapp1-ceeaz03 ..........138 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2053 EXC: CREATE AVZ: clesb01-vapp1-ceeaz03 ..........139 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2165 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........140 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2155 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........141 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2159 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........142 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2168 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........143 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2161 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........144 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2028 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........145 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2153 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........146 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2167 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........147 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2050 EXC: CREATE AVZ: clesb01-vapp1-ceeaz03 ..........148 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2048 EXC: CREATE AVZ: clesb01-vapp1-ceeaz03 ..........149 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2052 EXC: CREATE AVZ: clesb01-vapp1-ceeaz03 ..........150 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2154 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........151 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2037 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........152 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2031 EXC: CREATE AVZ: clesb01-vapp1-ceeaz02 ..........153 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2156 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........154 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2162 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........155 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2163 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........156 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2160 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........157 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2056 EXC: CREATE AVZ: clesb01-vapp1-ceeaz03 ..........158 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2170 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........159 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2054 EXC: CREATE AVZ: clesb01-vapp1-ceeaz03 ..........160 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2046 EXC: CREATE AVZ: clesb01-vapp1-ceeaz02 ..........161 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2012 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00 ..........162 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2001 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00 ..........163 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2020 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........164 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2038 EXC: CREATE AVZ: clesb01-vapp1-ceeaz02 ..........165 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2006 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........166 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2035 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........167 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2018 EXC: CREATE AVZ: clesb01-vapp1-ceeaz03 ..........168 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2034 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........169 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2166 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........170 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2041 EXC: CREATE AVZ: clesb01-vapp1-ceeaz03 ..........171 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2051 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........172 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2169 EXC: CREATE AVZ: clesb01-vapp1-ceeaz04 ..........173 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2058 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........174 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2069 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........175 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2059 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........176 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2068 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........177 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2067 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........178 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2061 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........179 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2070 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........180 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2060 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........181 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2066 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........182 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2065 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........183 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2062 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........184 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2057 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........185 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2073 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........186 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2071 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........187 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2072 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........188 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2075 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........189 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2064 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........190 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2063 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........191 of 192
# SCHEDULER SERVER: INITIALIZATION SERVER: p-clesb01-csu-2164 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01 ..........192 of 192
# SCHEDULER VM: INITIALIZATION VM: EIR_LRY_PL-1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2002 ..........1 of 605
# SCHEDULER VM: INITIALIZATION VM: EIR_LRY_PL-2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2006 ..........2 of 605
# SCHEDULER VM: INITIALIZATION VM: vAAALRY01_PL-3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2017 ..........3 of 605
# SCHEDULER VM: INITIALIZATION VM: vAAALRY01_PL-4 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2061 ..........4 of 605
# SCHEDULER VM: INITIALIZATION VM: vAAALRY01_SC-1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2060 ..........5 of 605
# SCHEDULER VM: INITIALIZATION VM: vAAALRY01_SC-2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2030 ..........6 of 605
# SCHEDULER VM: INITIALIZATION VM: vBGFLRY01-0 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2068 ..........7 of 605
# SCHEDULER VM: INITIALIZATION VM: vBGFLRY01-1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2070 ..........8 of 605
# SCHEDULER VM: INITIALIZATION VM: vBGFLRY01-2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2026 ..........9 of 605
# SCHEDULER VM: INITIALIZATION VM: vBGFLRY01-3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2016 ..........10 of 605
# SCHEDULER VM: INITIALIZATION VM: vBGFLRY01-4 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2039 ..........11 of 605
# SCHEDULER VM: INITIALIZATION VM: vBGFLRY01-5 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2057 ..........12 of 605
# SCHEDULER VM: INITIALIZATION VM: vCSCFLRY01_PL-3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2026 ..........13 of 605
# SCHEDULER VM: INITIALIZATION VM: vCSCFLRY01_PL-4 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2068 ..........14 of 605
# SCHEDULER VM: INITIALIZATION VM: vCSCFLRY01_SC-1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2061 ..........15 of 605
# SCHEDULER VM: INITIALIZATION VM: vCSCFLRY01_SC-2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2026 ..........16 of 605
# SCHEDULER VM: INITIALIZATION VM: vCSCFLRY01_VM-0 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2029 ..........17 of 605
# SCHEDULER VM: INITIALIZATION VM: vCSCFLRY01_VM-1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2021 ..........18 of 605
# SCHEDULER VM: INITIALIZATION VM: vCSCFLRY01_VM-10 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2062 ..........19 of 605
# SCHEDULER VM: INITIALIZATION VM: vCSCFLRY01_VM-2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2025 ..........20 of 605
# SCHEDULER VM: INITIALIZATION VM: vCSCFLRY01_VM-3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2060 ..........21 of 605
# SCHEDULER VM: INITIALIZATION VM: vCSCFLRY01_VM-4 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2014 ..........22 of 605
# SCHEDULER VM: INITIALIZATION VM: vCSCFLRY01_VM-5 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2160 ..........23 of 605
# SCHEDULER VM: INITIALIZATION VM: vCSCFLRY01_VM-6 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2032 ..........24 of 605
# SCHEDULER VM: INITIALIZATION VM: vCSCFLRY01_VM-7 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2070 ..........25 of 605
# SCHEDULER VM: INITIALIZATION VM: vCSCFLRY01_VM-8 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2058 ..........26 of 605
# SCHEDULER VM: INITIALIZATION VM: vCSCFLRY01_VM-9 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2017 ..........27 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_PL_2_3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2046 ..........28 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_PL_2_4 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2056 ..........29 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_SC_2_1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2007 ..........30 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_SC_2_2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2031 ..........31 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_x_0 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2044 ..........32 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_x_1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2046 ..........33 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_x_10 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2045 ..........34 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_x_11 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2044 ..........35 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_x_12 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2044 ..........36 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_x_13 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2034 ..........37 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_x_14 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2042 ..........38 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_x_2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2043 ..........39 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_x_3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2042 ..........40 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_x_4 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2042 ..........41 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_x_5 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2034 ..........42 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_x_6 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2045 ..........43 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_x_7 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2043 ..........44 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_x_8 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2044 ..........45 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_x_9 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2034 ..........46 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_y_0 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2049 ..........47 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_y_1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2054 ..........48 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_y_10 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2053 ..........49 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_y_11 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2049 ..........50 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_y_12 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2035 ..........51 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_y_13 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2052 ..........52 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_y_14 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2054 ..........53 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_y_2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2035 ..........54 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_y_3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2052 ..........55 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_y_4 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2054 ..........56 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_y_5 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2052 ..........57 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_y_6 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2054 ..........58 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_y_7 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2035 ..........59 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_y_8 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2035 ..........60 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY1_scaleout_PL_y_9 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2049 ..........61 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_PL_2_3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2050 ..........62 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_PL_2_4 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2012 ..........63 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_SC_2_1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2024 ..........64 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_SC_2_2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz02  NODE_SELECT: p-cllry01-csu-2046 ..........65 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_x_0 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2056 ..........66 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_x_1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2051 ..........67 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_x_10 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2053 ..........68 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_x_11 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2048 ..........69 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_x_12 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2048 ..........70 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_x_13 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2051 ..........71 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_x_14 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2050 ..........72 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_x_2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2056 ..........73 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_x_3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2048 ..........74 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_x_4 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2053 ..........75 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_x_5 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2056 ..........76 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_x_6 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2048 ..........77 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_x_7 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2050 ..........78 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_x_8 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2053 ..........79 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_x_9 EXC: CREATE AVZ: cllry01-vapp1-ceeaz03  NODE_SELECT: p-cllry01-csu-2050 ..........80 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_y_0 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2008 ..........81 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_y_1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2009 ..........82 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_y_10 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2010 ..........83 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_y_11 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2001 ..........84 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_y_12 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2009 ..........85 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_y_13 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2009 ..........86 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_y_14 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2012 ..........87 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_y_2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2005 ..........88 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_y_3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2005 ..........89 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_y_4 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2002 ..........90 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_y_5 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2010 ..........91 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_y_6 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2001 ..........92 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_y_7 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2013 ..........93 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_y_8 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2011 ..........94 of 605
# SCHEDULER VM: INITIALIZATION VM: vCUDBLRY2_scaleout_PL_y_9 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2010 ..........95 of 605
# SCHEDULER VM: INITIALIZATION VM: vDNSLRY01_PL-3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2068 ..........96 of 605
# SCHEDULER VM: INITIALIZATION VM: vDNSLRY01_PL-4 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2070 ..........97 of 605
# SCHEDULER VM: INITIALIZATION VM: vDNSLRY01_SC-1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2025 ..........98 of 605
# SCHEDULER VM: INITIALIZATION VM: vDNSLRY01_SC-2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2021 ..........99 of 605
# SCHEDULER VM: INITIALIZATION VM: vDSCLRY1-PL-3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2020 ..........100 of 605
# SCHEDULER VM: INITIALIZATION VM: vDSCLRY1-PL-4 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2040 ..........101 of 605
# SCHEDULER VM: INITIALIZATION VM: vDSCLRY1-PLScaled-1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2027 ..........102 of 605
# SCHEDULER VM: INITIALIZATION VM: vDSCLRY1-PLScaled-2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2027 ..........103 of 605
# SCHEDULER VM: INITIALIZATION VM: vDSCLRY1-PLScaled-3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2027 ..........104 of 605
# SCHEDULER VM: INITIALIZATION VM: vDSCLRY1-PLScaled-4 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2037 ..........105 of 605
# SCHEDULER VM: INITIALIZATION VM: vDSCLRY1-PLScaled-5 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2037 ..........106 of 605
# SCHEDULER VM: INITIALIZATION VM: vDSCLRY1-PLScaled-6 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2027 ..........107 of 605
# SCHEDULER VM: INITIALIZATION VM: vDSCLRY1-PLScaled-7 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2037 ..........108 of 605
# SCHEDULER VM: INITIALIZATION VM: vDSCLRY1-PLScaled-8 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2036 ..........109 of 605
# SCHEDULER VM: INITIALIZATION VM: vDSCLRY1-PLScaled-9 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2061 ..........110 of 605
# SCHEDULER VM: INITIALIZATION VM: vDSCLRY1-SC-1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2037 ..........111 of 605
# SCHEDULER VM: INITIALIZATION VM: vDSCLRY1-SC-2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2036 ..........112 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGCLRY01_vrp-31 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2061 ..........113 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGCLRY01_vrp-32 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2027 ..........114 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGCLRY01_vsfo-cp-1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2028 ..........115 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGCLRY01_vsfo-cp-2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2040 ..........116 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGCLRY01_vsfo-cp-3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2058 ..........117 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGCLRY01_vsfo-cp-4 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2062 ..........118 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGCLRY01_vsfo-cp-5 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2057 ..........119 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGCLRY01_vsfo-cp-6 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2024 ..........120 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGCLRY01_vsfo-cp-7 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2169 ..........121 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGCLRY01_vsfo-cp-8 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2017 ..........122 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGCLRY01_vsfo-cp-9 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2160 ..........123 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vRPs-31 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2020 ..........124 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vRPs-32 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2022 ..........125 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2166 ..........126 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-10 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2158 ..........127 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-11 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2156 ..........128 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-12 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2155 ..........129 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-13 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2151 ..........130 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-14 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2163 ..........131 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-15 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2170 ..........132 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-16 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2157 ..........133 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-17 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2162 ..........134 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2167 ..........135 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2153 ..........136 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-4 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2164 ..........137 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-5 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2164 ..........138 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-6 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2159 ..........139 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-7 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2165 ..........140 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-8 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2161 ..........141 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY01_epg_vsfo_pp-9 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2168 ..........142 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vRPs-31 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2037 ..........143 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vRPs-32 EXC: CREATE AVZ: cllry01-vapp1-ceeaz01  NODE_SELECT: p-cllry01-csu-2032 ..........144 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2157 ..........145 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-10 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2166 ..........146 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-11 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2154 ..........147 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-12 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2165 ..........148 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-13 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2153 ..........149 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-14 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2163 ..........150 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-15 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2156 ..........151 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-16 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2162 ..........152 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-17 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2161 ..........153 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2168 ..........154 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2154 ..........155 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-4 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2151 ..........156 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-5 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2159 ..........157 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-6 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2167 ..........158 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-7 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2158 ..........159 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-8 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2170 ..........160 of 605
# SCHEDULER VM: INITIALIZATION VM: vEPGULRY02_epg_vsfo_pp-9 EXC: CREATE AVZ: cllry01-vapp1-ceeaz04  NODE_SELECT: p-cllry01-csu-2155 ..........161 of 605
# SCHEDULER VM: INITIALIZATION VM: vHLRLRY1_AP-A EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2006 ..........162 of 605
# SCHEDULER VM: INITIALIZATION VM: vHLRLRY1_AP-B EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2004 ..........163 of 605
# SCHEDULER VM: INITIALIZATION VM: vHLRLRY1_BC0 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2006 ..........164 of 605
# SCHEDULER VM: INITIALIZATION VM: vHLRLRY1_BC1 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2013 ..........165 of 605
# SCHEDULER VM: INITIALIZATION VM: vHLRLRY1_BC2 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2008 ..........166 of 605
# SCHEDULER VM: INITIALIZATION VM: vHLRLRY1_CP1-A EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2003 ..........167 of 605
# SCHEDULER VM: INITIALIZATION VM: vHLRLRY1_CP1-B EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2004 ..........168 of 605
# SCHEDULER VM: INITIALIZATION VM: vHSSLRY1-pl-3 EXC: CREATE AVZ: cllry01-vapp1-ceeaz00  NODE_SELECT: p-cllry01-csu-2004 ..........169 of 605
# ...
# SCHEDULER VM: INITIALIZATION VM: vHSSESB2-scaled_out-node-5 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00  NODE_SELECT: p-clesb01-csu-2007 ..........496 of 605
# SCHEDULER VM: INITIALIZATION VM: vHSSESB2-scaled_out-node-6 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00  NODE_SELECT: p-clesb01-csu-2005 ..........497 of 605
# SCHEDULER VM: INITIALIZATION VM: vINTESB01 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2025 ..........498 of 605
# SCHEDULER VM: INITIALIZATION VM: vIPWEDNSESB01_PL-3 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2034 ..........499 of 605
# SCHEDULER VM: INITIALIZATION VM: vIPWEDNSESB01_PL-4 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2025 ..........500 of 605
# SCHEDULER VM: INITIALIZATION VM: vIPWEDNSESB01_SC-1 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2021 ..........501 of 605
# SCHEDULER VM: INITIALIZATION VM: vIPWEDNSESB01_SC-2 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2039 ..........502 of 605
# SCHEDULER VM: INITIALIZATION VM: vIPWIDNSESB01_PL-3 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2037 ..........503 of 605
# SCHEDULER VM: INITIALIZATION VM: vIPWIDNSESB01_PL-4 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2026 ..........504 of 605
# SCHEDULER VM: INITIALIZATION VM: vIPWIDNSESB01_SC-1 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2017 ..........505 of 605
# SCHEDULER VM: INITIALIZATION VM: vIPWIDNSESB01_SC-2 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2029 ..........506 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_FSB1-001 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2075 ..........507 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_FSB2-001 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2059 ..........508 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-001 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2067 ..........509 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-002 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2019 ..........510 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-003 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2071 ..........511 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-004 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2064 ..........512 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-005 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2070 ..........513 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-006 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2014 ..........514 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-007 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2066 ..........515 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-008 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2073 ..........516 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-009 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2073 ..........517 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-010 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2019 ..........518 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-011 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2066 ..........519 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-012 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2068 ..........520 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-013 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2070 ..........521 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-014 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2051 ..........522 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-015 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2067 ..........523 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-016 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2072 ..........524 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-017 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2057 ..........525 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-018 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2006 ..........526 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-019 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2068 ..........527 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-020 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2071 ..........528 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-021 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2051 ..........529 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-022 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2069 ..........530 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-023 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2006 ..........531 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-024 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2057 ..........532 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-025 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2069 ..........533 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_GPB-026 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2072 ..........534 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_NCB-001 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2059 ..........535 of 605
# SCHEDULER VM: INITIALIZATION VM: vMMEESB01_NCB-002 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2024 ..........536 of 605
# SCHEDULER VM: INITIALIZATION VM: vMRFESB01-0 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2023 ..........537 of 605
# SCHEDULER VM: INITIALIZATION VM: vMRFESB01-1 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2058 ..........538 of 605
# SCHEDULER VM: INITIALIZATION VM: vMSCESB1_AP-A EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2036 ..........539 of 605
# SCHEDULER VM: INITIALIZATION VM: vMSCESB1_AP-B EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2063 ..........540 of 605
# SCHEDULER VM: INITIALIZATION VM: vMSCESB1_BC0 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2063 ..........541 of 605
# SCHEDULER VM: INITIALIZATION VM: vMSCESB1_BC1 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2027 ..........542 of 605
# SCHEDULER VM: INITIALIZATION VM: vMSCESB1_BC2 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2026 ..........543 of 605
# SCHEDULER VM: INITIALIZATION VM: vMSCESB1_BC3 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2065 ..........544 of 605
# SCHEDULER VM: INITIALIZATION VM: vMSCESB1_BC4 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2036 ..........545 of 605
# SCHEDULER VM: INITIALIZATION VM: vMSCESB1_CP1-A EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2025 ..........546 of 605
# SCHEDULER VM: INITIALIZATION VM: vMSCESB1_CP1-B EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2026 ..........547 of 605
# SCHEDULER VM: INITIALIZATION VM: vMSCESB1_CP2-A EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2036 ..........548 of 605
# SCHEDULER VM: INITIALIZATION VM: vMSCESB1_CP2-B EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2016 ..........549 of 605
# SCHEDULER VM: INITIALIZATION VM: vMSCESB1_IPLB1-A EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2039 ..........550 of 605
# SCHEDULER VM: INITIALIZATION VM: vMSCESB1_IPLB1-B EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2029 ..........551 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_PL-3 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2058 ..........552 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_PL-4 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2023 ..........553 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_SC-1 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2061 ..........554 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_SC-2 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2064 ..........555 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_scaled_VM-0 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2025 ..........556 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_scaled_VM-1 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2065 ..........557 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_scaled_VM-10 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2022 ..........558 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_scaled_VM-11 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2029 ..........559 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_scaled_VM-12 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2036 ..........560 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_scaled_VM-13 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2035 ..........561 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_scaled_VM-14 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2015 ..........562 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_scaled_VM-2 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2075 ..........563 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_scaled_VM-3 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2020 ..........564 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_scaled_VM-4 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2064 ..........565 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_scaled_VM-5 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2014 ..........566 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_scaled_VM-6 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2059 ..........567 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_scaled_VM-7 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2024 ..........568 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_scaled_VM-8 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2039 ..........569 of 605
# SCHEDULER VM: INITIALIZATION VM: vMTASESB01_scaled_VM-9 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2017 ..........570 of 605
# SCHEDULER VM: INITIALIZATION VM: vSBGESB01_PL-0 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2040 ..........571 of 605
# SCHEDULER VM: INITIALIZATION VM: vSBGESB01_PL-1 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2017 ..........572 of 605
# SCHEDULER VM: INITIALIZATION VM: vSBGESB01_PL-2 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2059 ..........573 of 605
# SCHEDULER VM: INITIALIZATION VM: vSBGESB01_PL-3 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2021 ..........574 of 605
# SCHEDULER VM: INITIALIZATION VM: vSBGESB01_PL-4 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2037 ..........575 of 605
# SCHEDULER VM: INITIALIZATION VM: vSBGESB01_PL-5 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2062 ..........576 of 605
# SCHEDULER VM: INITIALIZATION VM: vSBGESB01_PL-6 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2060 ..........577 of 605
# SCHEDULER VM: INITIALIZATION VM: vSBGESB01_PL-7 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2020 ..........578 of 605
# SCHEDULER VM: INITIALIZATION VM: vSBGESB01_PL-8 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2061 ..........579 of 605
# SCHEDULER VM: INITIALIZATION VM: vSBGESB01_PL-9 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2016 ..........580 of 605
# SCHEDULER VM: INITIALIZATION VM: vSBGESB01_SC-1 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2028 ..........581 of 605
# SCHEDULER VM: INITIALIZATION VM: vSBGESB01_SC-2 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2016 ..........582 of 605
# SCHEDULER VM: INITIALIZATION VM: vSCEFESB01_CCC0 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2034 ..........583 of 605
# SCHEDULER VM: INITIALIZATION VM: vSCEFESB01_CCC1 EXC: CREATE AVZ: clesb01-vapp1-ceeaz02  NODE_SELECT: p-clesb01-csu-2044 ..........584 of 605
# SCHEDULER VM: INITIALIZATION VM: vSCEFESB01_IOT0 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2022 ..........585 of 605
# SCHEDULER VM: INITIALIZATION VM: vSCEFESB01_IOT1 EXC: CREATE AVZ: clesb01-vapp1-ceeaz02  NODE_SELECT: p-clesb01-csu-2042 ..........586 of 605
# SCHEDULER VM: INITIALIZATION VM: vSCEFESB01_PS01 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2034 ..........587 of 605
# SCHEDULER VM: INITIALIZATION VM: vSCEFESB01_PS02 EXC: CREATE AVZ: clesb01-vapp1-ceeaz02  NODE_SELECT: p-clesb01-csu-2042 ..........588 of 605
# SCHEDULER VM: INITIALIZATION VM: vSCEFESB01_PS03 EXC: CREATE AVZ: clesb01-vapp1-ceeaz03  NODE_SELECT: p-clesb01-csu-2052 ..........589 of 605
# SCHEDULER VM: INITIALIZATION VM: vSCEFESB01_PS04 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2036 ..........590 of 605
# SCHEDULER VM: INITIALIZATION VM: vSCEFESB01_PS05 EXC: CREATE AVZ: clesb01-vapp1-ceeaz02  NODE_SELECT: p-clesb01-csu-2045 ..........591 of 605
# SCHEDULER VM: INITIALIZATION VM: vSCEFESB01_PS06 EXC: CREATE AVZ: clesb01-vapp1-ceeaz03  NODE_SELECT: p-clesb01-csu-2052 ..........592 of 605
# SCHEDULER VM: INITIALIZATION VM: vSCEFESB01_SBM0 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2022 ..........593 of 605
# SCHEDULER VM: INITIALIZATION VM: vSCEFESB01_SBM1 EXC: CREATE AVZ: clesb01-vapp1-ceeaz02  NODE_SELECT: p-clesb01-csu-2042 ..........594 of 605
# SCHEDULER VM: INITIALIZATION VM: vSCEFESB01_SLB-01 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2023 ..........595 of 605
# SCHEDULER VM: INITIALIZATION VM: vSCEFESB01_SLB-02 EXC: CREATE AVZ: clesb01-vapp1-ceeaz02  NODE_SELECT: p-clesb01-csu-2042 ..........596 of 605
# SCHEDULER VM: INITIALIZATION VM: vWMGESB01_vrp-21 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2027 ..........597 of 605
# SCHEDULER VM: INITIALIZATION VM: vWMGESB01_vrp-22 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2036 ..........598 of 605
# SCHEDULER VM: INITIALIZATION VM: vWMGESB01_vsfo-wmg-1 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2028 ..........599 of 605
# SCHEDULER VM: INITIALIZATION VM: vWMGESB01_vsfo-wmg-2 EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2033 ..........600 of 605
# SCHEDULER VM: INITIALIZATION VM: vaat EXC: CREATE AVZ: clesb01-vapp1-ceeaz01  NODE_SELECT: p-clesb01-csu-2026 ..........601 of 605
# SCHEDULER VM: INITIALIZATION VM: vedaesb1-1 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00  NODE_SELECT: p-clesb01-csu-2008 ..........602 of 605
# SCHEDULER VM: INITIALIZATION VM: vedaesb1-2 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00  NODE_SELECT: p-clesb01-csu-2004 ..........603 of 605
# SCHEDULER VM: INITIALIZATION VM: vedaesb1-3 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00  NODE_SELECT: p-clesb01-csu-2001 ..........604 of 605
# SCHEDULER VM: INITIALIZATION VM: vedaesb1-resource-0 EXC: CREATE AVZ: clesb01-vapp1-ceeaz00  NODE_SELECT: p-clesb01-csu-2012 ..........605 of 605
# AVZ tables...vedaesb1-resource-0 in Server: p-clesb01-csu-2012
# Creating Server tables...
# Creating VMs tables...

# %%
parser = argparse.ArgumentParser(description='Processor of Template - NFVI Report')
parser.add_argument('-f', '--file', type=str, required=True, help='XLS file of the NFVi Template')


DIR_TEMPLATE = '/usr/app/template/'

if __name__ == '__main__':
    
    args = parser.parse_args()
    
    file_path = DIR_TEMPLATE + args.file
    
    if os.path.isfile(file_path):
        print ("File found .......... OK: %s"%file_path)
    else:
        raise Exception("File not exist: %s"%file_path)
    
    
    print("reading FILE: Servers Types")
    SERVER_TYPES = format_server_types(file_path)

    print("reading FILE: Flavors VMs")
    FLAVORS_VM = format_flavors_df(file_path)

    print("reading FILE: Servers")
    SERVERS_DF = format_server_df(file_path)

    print("reading FILE: VMs")
    VMS_DF = format_vms_df(file_path)


    print("reading FILE: Tasks")
    TASKS_DF = format_task_df(file_path)

    print("Testing files...")
    CHECK_OK = True

    print("Chequeando correspondencia en Servers DB.........", end='')
    _test1 = ~SERVERS_DF.loc[SERVERS_DF['Task_Action'] == 'CREATE','Server_Type'].isin([x.name for x in SERVER_TYPES])

    if np.any(_test1):
        print('NOK')
        print("\t\tERROR SERVERS DB:  No esta definido el Type Server en index: %d "%_test1.idxmax())
        CHECK_OK = False
    else:
        print("OK")


    print("Chequeando correspondencia en VM DB.........", end='')
    _test2 = ~VMS_DF.loc[VMS_DF['Task_Action'] == 'CREATE','Flavor'].isin([x.name for x in FLAVORS_VM])

    if np.any(_test2):
        print('NOK')
        display(VMS_DF[_test2])
        print("\t\tERROR VM DB:  No esta definido el Flavor en index: %d "%_test2.idxmax())
        CHECK_OK = False
    else:
        print("OK")

    DEFAULT_SERVER = Server('default_server',SERVER_TYPES[0],'default', 'default', virtual=True)


    if not CHECK_OK:
        raise Exception('Archivo de INPUT contiene fallas')

    
    TASKS  = G_Tasks('PRI_TASK',TASKS_DF.values, SERVERS_DF, VMS_DF, DEFAULT_SERVER)
    exec_tasks(TASKS, 'INITIALIZATION')
    
    
    
    SAVE_DATA = defaultdict(lambda x: None)

    print("AVZ tables...")
    AVZ_TABLES = {_node:TASKS.get_scheduler(_node).get_status_by_avz()  for _node in TASKS.nodes() if _node != 'ROOT'}
    for k,v in AVZ_TABLES.items():
        v['utilization'] = v['utilization'].apply(lambda x: "%0.0f%%"%(100*x)) 

    SAVE_DATA['AVZ_TABLES'] = {k:v.to_dict() for k,v in AVZ_TABLES.items()}


    print("Creating Server tables...")
    SERVERS_TABLES = {_node:TASKS.get_scheduler(_node).get_servers_status()  for _node in TASKS.nodes() if _node != 'ROOT'}
    for k,v in SERVERS_TABLES.items():
        v.loc[:,['id','memory','server_type','vcpus','vcpus_free','vcpus_reserved','vcpus_system','vms']] = v.loc[:,['id','memory','server_type','vcpus','vcpus_free','vcpus_reserved','vcpus_system','vms']].astype(int)

    SAVE_DATA['SERVERS_TABLES'] = {k:v.to_dict() for k,v in SERVERS_TABLES.items()}  


    print("Creating VMs tables...")
    VMS_TABLES = {_node:TASKS.get_scheduler(_node).get_vms_status()  for _node in TASKS.nodes() if _node != 'ROOT'}
    for k,v in VMS_TABLES.items():
        v.loc[:,['vcpus','memory']] = v.loc[:,['vcpus','memory']].astype(int) 

    SAVE_DATA['VMS_TABLES'] = {k:v.to_dict() for k,v in VMS_TABLES.items()}
    SAVE_DATA['SIMULATIONS_LIST'] = [_ed for _ed in TASKS.edges(data=True) if _ed[0] != 'ROOT'] 
    SAVE_DATA['SERVER_TYPES'] = [_server_type.get_info().to_dict('records')[0] for i,_server_type in  enumerate(SERVER_TYPES)]
    SAVE_DATA['FLAVORS_VM'] = [_flavor_vm.get_info().to_dict('records')[0] for i,_flavor_vm in  enumerate(FLAVORS_VM)]
    SAVE_DATA['STATE_LIST'] = [_node for _node in TASKS.nodes() if _node != 'ROOT']
    
    
    
    _file_out = file_path.replace('.xlsx','.json')
    print("Saving file in: %s"%_file_out)

    with open(_file_out, 'w') as outfile:
        json.dump(dict(SAVE_DATA), outfile)

# %%
# !jupyter nbconvert \
    --TagRemovePreprocessor.enabled=True \
    --TagRemovePreprocessor.remove_cell_tags="['COMPILE']" \
    --TemplateExporter.exclude_markdown=True \
    --to python "PROCESSOR.ipynb" --output processor_1

# !sed 's/env\ python/env python3/' processor_1.py > processor.py
# !rm processor_1.py
